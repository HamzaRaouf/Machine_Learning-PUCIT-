# %% [markdown]
# # K-Means Clustering algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Step 1: Generate random data for two clusters
np.random.seed(42)

# Cluster 1: centered at (2, 2)
cluster_1 = np.random.randn(100, 2) + np.array([2, 2])

# Cluster 2: centered at (7, 7)
cluster_2 = np.random.randn(100, 2) + np.array([7, 7])

# Combine the data into one dataset
data = np.vstack([cluster_1, cluster_2])

# %%
# Step 2: Visualize the randomly generated data
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c='gray', marker='o', label='Data points')
plt.title('Randomly Generated Data')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# %% [markdown]
# ## Two Clusters Solution, K=2

# %%
# Step 3: Apply K-Means clustering algorithm
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(data)
# Out:
# C:\Users\adeel\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=42)

# %%
# Step 4: Visualize the data after clustering and show centroids
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=kmeans.labels_, cmap='viridis', marker='o', label='Data points')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title('K-Means Clustering Results with Centroids')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Three Clusters Solution, K=3

# %%
# Step 3: Apply K-Means clustering algorithm
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(data)

# %%
# Step 4: Visualize the data after clustering and show centroids
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=kmeans.labels_, cmap='viridis', marker='o', label='Data points')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title('K-Means Clustering Results with Centroids')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Four Clusters Solution, K=4

# %%
# Step 3: Apply K-Means clustering algorithm
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(data)

# %%
# Step 4: Visualize the data after clustering and show centroids
plt.figure(figsize=(8, 6))
plt.scatter(data[:, 0], data[:, 1], c=kmeans.labels_, cmap='viridis', marker='o', label='Data points')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', marker='X', label='Centroids')
plt.title('K-Means Clustering Results with Centroids')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend()
plt.show()
